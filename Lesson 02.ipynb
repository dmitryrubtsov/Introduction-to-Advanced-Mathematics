# %% [markdown]
# # Lesson 2

# %% [markdown]
# ## Задание 1
# Даны два вектора в трехмерном пространстве: (20,20,20) и (0,0,-20)
# Найдите их сумму. (на листочке)
# Напишите код на Python, реализующий расчет длины вектора, заданного его координатами. (в программе)

# %% [markdown]
# $\overrightarrow{a} = (20, 20, 20$
# $\overrightarrow{b} = (0, 0, -20)$
# $\overrightarrow{ab} = ((20 + 0), (20 + 0), (20 + (-20))) = (20, 20, 0)$

# %%
import numpy as np
import math

# %%
a = np.array([20, 20, 20])
b = np.array([0, 0, -20])

# %%
c = a + b
print(c)
print(math.sqrt(c[0]**2 + c[1]**2 + c[2]**2))
print(np.linalg.norm(c))
# Out:
# [20 20  0]
# 28.284271247461902
# 28.284271247461902

# %% [markdown]
# ## Задание 2 (на листочке)
# Почему прямые не кажутся перпендикулярными? (см.ролик)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
x = np.linspace(-5, 5, 21)
y = 3 * x + 1
y2 = -(1/3) * x + 1

plt.plot(x, y)
plt.plot(x, y2)
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# Из-за разного маштаба осей.

# %%
x = np.linspace(-5, 5, 21)
y = 3 * x + 1
y2 = -(1/3) * x + 1

plt.plot(x, y)
plt.plot(x, y2)
plt.xlabel('x')
plt.ylabel('y')
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Задание 3 (в программе)
# Напишите код на Python, реализующий построение графиков:
# 1. окружности,
# 1. эллипса,
# 1. гиперболы.

# %%
x = np.linspace(-10, 10, 100)
R = 10
y = np.sqrt(R**2 - x**2)
y2 = -np.sqrt(R**2 - x**2)

plt.plot(x, y)
plt.plot(x, y2)
plt.xlabel('x')
plt.ylabel('y')
plt.axis('equal')
plt.show()

# %%
t = np.arange(0, np.pi * 2.0, 0.01)
r = 10
x = r * np.cos(t)
y = r * np.sin(t)
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.axis('equal')
plt.show()

# %%
x = np.linspace(-10, 10, 150)
a = 10
b = 3
y = np.sqrt((1-x**2/a**2)*b**2)
y2 = -np.sqrt((1-x**2/a**2)*b**2)

plt.plot(x, y)
plt.plot(x, y2)
plt.xlabel('x')
plt.ylabel('y')
plt.axis('equal')
plt.show()

# %%
t = np.arange(0, np.pi * 2.0, 0.01)
a = 10
b = 3
x = a * np.cos(t)
y = b * np.sin(t)
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.axis('equal')
plt.show()

# %%
x = np.linspace(-20, 20, 150)
a = 3
b = 2
y = np.sqrt((1+x**2/a**2)*b**2)
y2 = -np.sqrt((1+x**2/a**2)*b**2)

plt.plot(x, y)
plt.plot(x, y2)
plt.xlabel('x')
plt.ylabel('y')
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Задание 4 (на листочке)
# 1. Пусть задана плоскость:
# $
# A\bullet x + B \bullet y + C \bullet z + D = 0
# $.
# Напишите уравнение плоскости, параллельной данной и проходящей через начало координат.
# 1.  Пусть задана плоскость: $A_1x + B_1y + C_1z + D_1 = 0$
# и прямая:
# $\frac{x-x_1}{x_2-x_1} = \frac{y-y_1}{y_2-y_1} = \frac{z-z_1}{z_2-z_1}$
# Как узнать, принадлежит прямая плоскости или нет?

# %% [markdown]
# 1. $\alpha = A\bullet x + B \bullet y + C \bullet z + D = 0$
# $\overrightarrow{n} = (A, B, C)$
# $\beta = A\bullet(x - x_1) + B\bullet(y - y_1) + C\bullet(z - z_1) = 0$
# $x_1 = 0, y_1 = 0, z_1 = 0$
# $\beta = A\bullet x + B\bullet y + C\bullet z = 0$
#
# 1. $\left\{
# \begin{array}{l}
# A_1x_1 + B_1y_1 + C_1z_1 + D_1 = 0 \\
# A_1x_2 + B_1y_2 + C_1z_2 + D_1 = 0
# \end{array}
# \right.$

# %% [markdown]
# ## Задание 5 (в программе)
# 1. Нарисуйте трехмерный график двух параллельных плоскостей.
# 1. Нарисуйте трехмерный график двух любых поверхностей второго порядка.

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ### 1.

# %%
x = np.linspace(-1,1,10)
y = np.linspace(-1,1,10)
X,Y = np.meshgrid(x,y)
Z= 4*X + 8*Y + 1

X1,Y1 = np.meshgrid(x,y)
Z1= 4*X1 + 8*Y1 + 10

fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_surface(X, Y, Z)
ax.plot_surface(X1, Y1, Z1)
plt.show()

# %% [markdown]
# ### 2.

# %%
u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(0, np.pi, 100)

x = 10 * np.outer(np.cos(u), np.sin(v))
y = 5 * np.outer(np.sin(u), np.sin(v))
z = 3 * np.outer(np.ones(np.size(u)), np.cos(v))

fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_surface(x, y, z)
plt.show()
